# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
data = pd.read_csv('BIKE_DETAILS.csv')
data
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
print(len(data))
# Out:
# 1061

# %%
data.shape
# Out:
# (1061, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.1+ KB

# %%
data.dtypes
# Out:
# name                  object
# selling_price          int64
# year                   int64
# seller_type           object
# owner                 object
# km_driven              int64
# ex_showroom_price    float64
# dtype: object

# %%
data.isnull()
# Out:
#        name  selling_price   year  seller_type  owner  km_driven  \
# 0     False          False  False        False  False      False
# 1     False          False  False        False  False      False
# 2     False          False  False        False  False      False
# 3     False          False  False        False  False      False
# 4     False          False  False        False  False      False
# ...     ...            ...    ...          ...    ...        ...
# 1056  False          False  False        False  False      False
# 1057  False          False  False        False  False      False
# 1058  False          False  False        False  False      False
# 1059  False          False  False        False  False      False
# 1060  False          False  False        False  False      False
#
#       ex_showroom_price
# 0                  True
# 1                  True
# 2                 False
# 3                 False
# 4                  True
# ...                 ...
# ...

# %%
data.isnull().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
data.head(10)
# Out:
#                                    name  selling_price  year seller_type  \
# 0             Royal Enfield Classic 350         175000  2019  Individual
# 1                             Honda Dio          45000  2017  Individual
# 2   Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3     Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                 Yamaha SZ [2013-2014]          20000  2011  Individual
# 5                      Honda CB Twister          18000  2010  Individual
# 6                  Honda CB Hornet 160R          78500  2018  Individual
# 7  Royal Enfield Bullet 350 [2007-2011]         180000  2008  Individual
# 8                Hero Honda CBZ extreme          30000  2010  Individual
# 9                    Bajaj Discover 125          50000  2016  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# ...

# %%
data.tail(10)
# Out:
#                     name  selling_price  year seller_type      owner  \
# 1051  Bajaj Discover 125          20000  2014  Individual  2nd owner
# 1052           Hero Hunk          20000  2009  Individual  2nd owner
# 1053  Hero  Ignitor Disc          20000  2015  Individual  2nd owner
# 1054    Hero  CBZ Xtreme          20000  2010  Individual  1st owner
# 1055       Bajaj  ct 100          18000  2017  Individual  1st owner
# 1056           Activa 3g          17000  2010  Individual  1st owner
# 1057    Honda CB twister          16000  2012  Individual  1st owner
# 1058  Bajaj Discover 125          15000  2013  Individual  2nd owner
# 1059      Honda CB Shine          12000  2009  Individual  1st owner
# 1060    Bajaj Pulsar 150          10000  2008  Individual  1st owner
#
#       km_driven  ex_showroom_price
# 1051      25000            57000.0
# 1052      49000            75000.0
# 1053      24000            65000.0
# 1054      50000            78700.0
# ...

# %%
data.sort_values(by = ['selling_price'])
# Out:
#                                name  selling_price  year seller_type  \
# 543                       TVS Excel           5000  1998  Individual
# 748        Honda Activa [2000-2015]           6000  2006  Individual
# 567                     Bajaj Super           6000  1991  Individual
# 77                        Honda Dio           7500  2009  Individual
# 115         Hero Honda Passion Plus           7500  2004  Individual
# ..                              ...            ...   ...         ...
# 311      Harley-Davidson Street 750         330000  2014  Individual
# 13                    Yamaha YZF R3         365000  2019  Individual
# 289  Kawasaki Ninja 650 [2018-2019]         425000  2017  Individual
# 134      Harley-Davidson Street Bob         750000  2013  Individual
# 295                 Suzuki GSX S750         760000  2019  Individual
#
#          owner  km_driven  ex_showroom_price
# 543  1st owner      60000                NaN
# 748  2nd owner      35000            50267.0
# ...

# %%
data.sort_values(by = ['selling_price'], ascending = False)
# Out:
#                                name  selling_price  year seller_type  \
# 295                 Suzuki GSX S750         760000  2019  Individual
# 134      Harley-Davidson Street Bob         750000  2013  Individual
# 289  Kawasaki Ninja 650 [2018-2019]         425000  2017  Individual
# 13                    Yamaha YZF R3         365000  2019  Individual
# 311      Harley-Davidson Street 750         330000  2014  Individual
# ..                              ...            ...   ...         ...
# 77                        Honda Dio           7500  2009  Individual
# 115         Hero Honda Passion Plus           7500  2004  Individual
# 567                     Bajaj Super           6000  1991  Individual
# 748        Honda Activa [2000-2015]           6000  2006  Individual
# 543                       TVS Excel           5000  1998  Individual
#
#          owner  km_driven  ex_showroom_price
# 295  1st owner       2800           752020.0
# 134  2nd owner      12000          1278000.0
# ...

# %%
data.dtypes.value_counts()
# Out:
# int64      3
# object     3
# float64    1
# dtype: int64

# %%
data['name'].value_counts().head(10)
# Out:
# Bajaj Pulsar 150                 41
# Royal Enfield Classic 350        27
# Honda Activa [2000-2015]         23
# Honda CB Hornet 160R             22
# Bajaj Pulsar 180                 20
# Royal Enfield Thunderbird 350    19
# Hero Honda Splendor Plus         17
# Yamaha FZ S V 2.0                16
# Bajaj Discover 125               16
# Honda Shine                      15
# Name: name, dtype: int64

# %%
data['owner'].value_counts()
# Out:
# 1st owner    924
# 2nd owner    123
# 3rd owner     11
# 4th owner      3
# Name: owner, dtype: int64

# %%
data['seller_type'].value_counts()
# Out:
# Individual    1055
# Dealer           6
# Name: seller_type, dtype: int64

# %%
data['year'].value_counts().head(10)
# Out:
# 2017    133
# 2018    131
# 2016    107
# 2015    100
# 2014     91
# 2019     86
# 2013     73
# 2012     70
# 2011     61
# 2010     60
# Name: year, dtype: int64

# %%
data.rename(columns = {'owner':'prev_owners'})
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#      prev_owners  km_driven  ex_showroom_price
# ...

# %%
data.replace({'1st owner':1, '2nd owner':2, '3rd owner':3, '4th owner':4})
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#       owner  km_driven  ex_showroom_price
# ...

# %%
data
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
data.query('selling_price > 225000')
# Out:
#                                  name  selling_price  year seller_type  \
# 13                      Yamaha YZF R3         365000  2019  Individual
# 130  Royal Enfield Continental GT 650         299000  2019  Individual
# 134        Harley-Davidson Street Bob         750000  2013  Individual
# 261     Royal Enfield Interceptor 650         260000  2019  Individual
# 288                        KTM RC 390         270000  2019  Individual
# 289    Kawasaki Ninja 650 [2018-2019]         425000  2017  Individual
# 295                   Suzuki GSX S750         760000  2019  Individual
# 311        Harley-Davidson Street 750         330000  2014  Individual
# 315     Royal Enfield Interceptor 650         285000  2019  Individual
# 344                        BMW G310GS         300000  2018  Individual
# 407     Royal Enfield Interceptor 650         270000  2019  Individual
# 860    Kawasaki Ninja 650 [2018-2019]         300000  2011  Individual
# ...

# %%
data.pivot_table(index = 'year', values = 'selling_price', aggfunc = max).head(10)
# Out:
#       selling_price
# year
# 1988          20000
# 1991           6000
# 1993         130000
# 1995         150000
# 1997          25000
# 1998          65000
# 1999          15000
# 2000          70000
# 2001          60000
# 2002          27000

# %%
np.round(data.describe(), 2)
# Out:
#        selling_price     year  km_driven  ex_showroom_price
# count        1061.00  1061.00    1061.00             626.00
# mean        59638.15  2013.87   34359.83           87958.71
# std         56304.29     4.30   51623.15           77496.59
# min          5000.00  1988.00     350.00           30490.00
# 25%         28000.00  2011.00   13500.00           54852.00
# 50%         45000.00  2015.00   25000.00           72752.50
# 75%         70000.00  2017.00   43000.00           87031.50
# max        760000.00  2020.00  880000.00         1278000.00

# %%
data.drop(['year'], axis=1)
# Out:
#                                      name  selling_price seller_type  \
# 0               Royal Enfield Classic 350         175000  Individual
# 1                               Honda Dio          45000  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  Individual
# 4                   Yamaha SZ [2013-2014]          20000  Individual
# ...                                   ...            ...         ...
# 1056                            Activa 3g          17000  Individual
# 1057                     Honda CB twister          16000  Individual
# 1058                   Bajaj Discover 125          15000  Individual
# 1059                       Honda CB Shine          12000  Individual
# 1060                     Bajaj Pulsar 150          10000  Individual
#
#           owner  km_driven  ex_showroom_price
# 0     1st owner        350                NaN
# ...

# %%
data
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
top_bike_company = data['name'].value_counts().head(10)
plt.figure(figsize=(10, 8))
sns.barplot(x = top_bike_company, y = top_bike_company.index)
plt.ylabel('Name of the bike')
plt.title('Top 10 bike companies')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %%
sns.countplot(x = data['seller_type'], data = data)

# %%
sns.countplot(x = data['owner'], data = data)

# %%
data.plot('year', 'selling_price')

# %%
sns.lmplot(x = 'year', y = 'selling_price', data = data, aspect = 2, height = 6)
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.title('Year vs Selling Price - Linear Regression')
# Out:
# Text(0.5, 1, 'Year vs Selling Price - Linear Regression')

# %%
highest_bike_purchased_year = data['year'].value_counts().head(10)
highest_bike_purchased_year
# Out:
# 2017    133
# 2018    131
# 2016    107
# 2015    100
# 2014     91
# 2019     86
# 2013     73
# 2012     70
# 2011     61
# 2010     60
# Name: year, dtype: int64

# %%
sns.countplot(x = data['year'].head(10))

# %%
data['ex_showroom_price'].fillna(np.round(data['ex_showroom_price'].mean(), 2), inplace = True)

# %%
sns.distplot(data['ex_showroom_price'])

# %%
np.round(data['ex_showroom_price'], 2)
# Out:
# 0        87958.71
# 1        87958.71
# 2       148114.00
# 3        89643.00
# 4        87958.71
#           ...
# 1056     52000.00
# 1057     51000.00
# 1058     57000.00
# 1059     58000.00
# 1060     75000.00
# Name: ex_showroom_price, Length: 1061, dtype: float64

# %%
data.corr()
# Out:
#                    selling_price      year  km_driven  ex_showroom_price
# selling_price           1.000000  0.402188  -0.212937           0.750451
# year                    0.402188  1.000000  -0.288675           0.068111
# km_driven              -0.212937 -0.288675   1.000000          -0.082539
# ex_showroom_price       0.750451  0.068111  -0.082539           1.000000

# %%
plt.subplots(figsize = (10,10))
sns.heatmap(data.corr(), cmap = 'RdGy')

# %%
def bike_model(model_name, excl_honda_hero=False):
    model_list = []
    if excl_honda_hero:
        for i in data['name']:
            if model_name in i and 'Hero' not in i:
                model_list.append(i)
        return model_list
    else:
        for i in data['name']:
            if model_name in i:
                model_list.append(i)
        return model_list

# %%
royal_enfield = bike_model('Royal Enfield')
honda = bike_model('Honda', excl_honda_hero=True)
bajaj = bike_model('Bajaj')
yamaha = bike_model('Yamaha')
suzuki = bike_model('Suzuki')
hero = bike_model('Hero')
tvs = bike_model('TVS')
ktm = bike_model('KTM')

# %%
def brand(i):
    if i in royal_enfield:
        return 'Royal Enfield'
    elif i in honda:
        return 'Honda'
    elif i in bajaj:
        return 'Bajaj'
    elif i in yamaha:
        return 'Yamaha'
    elif i in hero:
        return 'Hero'    
    elif i in tvs:
        return 'TVS'    
    elif i in suzuki:
        return 'Suzuki'  
    elif i in ktm:
        return 'KTM' 
    else:
        return 'Other'

# %%
data['brand'] = data['name'].apply(lambda x: brand(x))
data.head(10)
# Out:
#                                    name  selling_price  year seller_type  \
# 0             Royal Enfield Classic 350         175000  2019  Individual
# 1                             Honda Dio          45000  2017  Individual
# 2   Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3     Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                 Yamaha SZ [2013-2014]          20000  2011  Individual
# 5                      Honda CB Twister          18000  2010  Individual
# 6                  Honda CB Hornet 160R          78500  2018  Individual
# 7  Royal Enfield Bullet 350 [2007-2011]         180000  2008  Individual
# 8                Hero Honda CBZ extreme          30000  2010  Individual
# 9                    Bajaj Discover 125          50000  2016  Individual
#
#        owner  km_driven  ex_showroom_price          brand
# 0  1st owner        350           87958.71  Royal Enfield
# ...

# %%
data['owner'] = data['owner'].map({'1st owner':1, '2nd owner':2, '3rd owner':3, '4th owner':4})
data.head(100)
# Out:
#                                    name  selling_price  year seller_type  \
# 0             Royal Enfield Classic 350         175000  2019  Individual
# 1                             Honda Dio          45000  2017  Individual
# 2   Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3     Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                 Yamaha SZ [2013-2014]          20000  2011  Individual
# ..                                  ...            ...   ...         ...
# 95                      Honda Activa 4G          45000  2018  Individual
# 96                          Yamaha FZ25         150000  2019  Individual
# 97                     Bajaj Pulsar 150          42000  2015  Individual
# 98                   Hero Splendor Plus          30000  2015  Individual
# 99                   Bajaj Discover 100          24999  2012  Individual
#
#     owner  km_driven  ex_showroom_price          brand
# ...

# %%
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
x = np.array(data[['selling_price','year','owner','km_driven']]).reshape(-1,4)
y = np.array(data['ex_showroom_price']).reshape(-1,1)

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(x).transform(x)
y = preprocessing.StandardScaler().fit(y).transform(y)
print(X[:5])
print(y[:5])
# Out:
# [[ 2.04986596  1.1939283  -0.3608646  -0.65912038]
#  [-0.26010548  0.72872157 -0.3608646  -0.55640485]
#  [ 1.60564068  0.96132494 -0.3608646  -0.43334002]
#  [ 0.09527474  0.26351484 -0.3608646  -0.22015684]
#  [-0.70433076 -0.66689862  2.12535192 -0.25891742]]
# [[-4.02488462e-08]
#  [-4.02488462e-08]
#  [ 1.01136731e+00]
#  [ 2.83172685e-02]
#  [-4.02488462e-08]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =  train_test_split(X,y,test_size=0.2)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit (X_train,y_train)
y_pred = model.predict(X_test)
print(y_pred[0:5])
# Out:
# [[-0.41344232]
#  [-0.04408626]
#  [-0.34722926]
#  [ 0.05144838]
#  [-0.28273408]]

# %%
print('R2:',model.score(X_train, y_train))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2: 0.5576043918897229
# MAE: 0.3627355177508893
# MSE: 0.9210578428859774
# RMSE: 0.9597175849623562
